# %%
using Graphs, Graphs.Experimental.ShortestPaths
using GraphIO
using GraphIO.NET
using Statistics
using DataFrames
using Random
using Distributions
using Plots, GraphRecipes
include("../Assignment 1/NetworkProcessing.jl")
# Out:
# WARNING: replacing module NetworkProcessing.
# Main.NetworkProcessing

# %%
graph, edge_weights = NetworkProcessing.read_network("A3_synthetic_networks/synthetic_network_N_300_blocks_5_prr_0.50_prs_0.02.net")
graph
# Out:
# {300, 5199} undirected simple Int64 graph

# %%
NetworkProcessing.network_num_descriptors(graph)
# Out:
# Number of nodes: 300
# Number of edges: 5199
# Degree -- Min: 22, Max: 47, Avg: 34.66
# Average Clustering Coefficient: 0.380610788045568
# Assortativity: -0.005713384490005372
# Average Path Length: 2.0922853957636565
# Diameter: 3
# 9-element Vector{Float64}:
#   300.0
#  5199.0
#    22.0
#    47.0
#    34.66
#     0.3806
#    -0.0057
#     2.0923
#     3.0

# %%
graphplot(graph, curves=false)

# %%
using Pkg

# %%
Pkg.add("CommunityDetection")
# Out:
#     Updating registry at `C:\Users\mario\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed FLANN ──────────────── v1.1.0
#    Installed ImageIO ────────────── v0.4.1
#    Installed StatsFuns ──────────── v0.9.18
#    Installed NetworkLayout ──────── v0.4.0
#    Installed GraphMakie ─────────── v0.2.3
#    Installed PNGFiles ───────────── v0.3.17
#    Installed CommunityDetection ─── v0.1.0
#    Installed GLMakie ────────────── v0.4.4
#    Installed Contour ────────────── v0.5.7
#    Installed Formatting ─────────── v0.4.3
#    Installed URIParser ──────────── v0.4.1
#    Installed CEnum ──────────────── v0.4.2
#    Installed Missings ───────────── v1.2.0
#    Installed Static ─────────────── v0.8.10
#    Installed BinDeps ────────────── v1.0.2
#    Installed EllipsisNotation ───── v1.8.0
#    Installed IrrationalConstants ── v0.1.1
#    Installed NaNMath ────────────── v0.3.7
#    Installed IfElse ─────────────── v0.1.1
# ...
